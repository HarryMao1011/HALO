# %%
from typing import Dict, Iterable, Optional
import scanpy as sc
import numpy as np
import torch
from torch.distributions import Normal, Poisson
from torch.distributions import kl_divergence as kld
import scvi
from scvi import REGISTRY_KEYS
from scvi._compat import Literal
from scvi.distributions import NegativeBinomial, ZeroInflatedNegativeBinomial
from scvi.module._peakvae import Decoder as DecoderPeakVI
from scvi.module.base import BaseModuleClass, LossRecorder, auto_move_data
from scvi.nn import DecoderSCVI, Encoder, FCLayers
from scvi.module import MULTIVAE

from anndata import AnnData
from typing import Dict, Iterable, List, Optional, Sequence, Union
from scvi.model import MULTIVI 
import pandas as pd
# Out:
# Global seed set to 0

# %%
adata_multi = sc.read_h5ad("halo/E18_mouse_Brain/multiomic.h5ad")
adata_multi.obs["batch_id"] = 1
adata_multi.var["modality"] =adata_multi.var["feature_types"]
adata_mvi = scvi.data.organize_multiome_anndatas(adata_multi)

# %%
adata_mvi
# Out:
# AnnData object with n_obs × n_vars = 3365 × 176722
#     obs: 'celltype', 'batch_id', 'modality'
#     var: 'gene_ids', 'feature_types', 'modality'

# %%
adata_mvi.obs.celltype
# Out:
# AAACAGCCAACCGCCA-1_paired        Upper Layer
# AAACAGCCAAGGTCGA-1_paired     RG, Astro, OPC
# AAACAGCCAGGAACAT-1_paired       Deeper Layer
# AAACAGCCATATTGAC-1_paired       Deeper Layer
# AAACAGCCATGGTTAT-1_paired           Subplate
#                                   ...
# TTTGTGGCATAATCGT-1_paired    Ependymal cells
# TTTGTGGCATTTGCTC-1_paired        Upper Layer
# TTTGTGTTCAATGACC-1_paired                IPC
# TTTGTTGGTGGAGCAA-1_paired       Deeper Layer
# TTTGTTGGTTAGAGCC-1_paired        Upper Layer
# Name: celltype, Length: 3365, dtype: category
# Categories (7, object): ['Upper Layer', 'Deeper Layer', 'V-SVZ', 'RG, Astro, OPC', 'Ependymal cells', 'IPC', 'Subplate']

# %%
import pandas as pd
df_meta= pd.read_csv("halo/E18_mouse_Brain/RNA/metadata.tsv",sep = "\t",index_col=0)

# %%
df_meta
# Out:
#                     n_counts         celltype  velo_s_norm_self_transition  \
# AAACAGCCAACCGCCA-1     681.0      Upper Layer                     0.057197
# AAACAGCCAAGGTCGA-1     296.0   RG, Astro, OPC                     0.114116
# AAACAGCCAGGAACAT-1     504.0     Deeper Layer                     0.082940
# AAACAGCCATATTGAC-1     321.0     Deeper Layer                     0.106146
# AAACAGCCATGGTTAT-1     432.0         Subplate                     0.103904
# ...                      ...              ...                          ...
# TTTGTGGCATAATCGT-1    1248.0  Ependymal cells                     0.089063
# TTTGTGGCATTTGCTC-1     451.0      Upper Layer                     0.049716
# TTTGTGTTCAATGACC-1     369.0              IPC                     0.130270
# TTTGTTGGTGGAGCAA-1     513.0     Deeper Layer                     0.038342
# TTTGTTGGTTAGAGCC-1     204.0      Upper Layer                     0.021775
#
#                     root_cells  end_points  velo_s_norm_pseudotime  \
# AAACAGCCAACCGCCA-1    0.037962    0.086987                0.857504
# AAACAGCCAAGGTCGA-1    0.049274    0.396248                0.213945
# AAACAGCCAGGAACAT-1    0.020133    0.338813                0.958743
# AAACAGCCATATTGAC-1    0.003566    0.735495                0.981135
# AAACAGCCATGGTTAT-1    0.036739    0.134693                0.848509
# ...                        ...         ...                     ...
# TTTGTGGCATAATCGT-1    0.556196    0.005403                0.889134
# TTTGTGGCATTTGCTC-1    0.013520    0.407998                0.861768
# TTTGTGTTCAATGACC-1    0.499946    0.019731                0.604746
# TTTGTTGGTGGAGCAA-1    0.062265    0.113687                0.948574
# TTTGTTGGTTAGAGCC-1    0.038538    0.360803                0.895777
#
#                     latent_time       binned
# AAACAGCCAACCGCCA-1     0.604954  (0.6, 0.65]
# AAACAGCCAAGGTCGA-1     0.281341  (0.25, 0.3]
# AAACAGCCAGGAACAT-1     0.851495  (0.85, 0.9]
# AAACAGCCATATTGAC-1     0.982605  (0.95, 1.0]
# AAACAGCCATGGTTAT-1     0.549869  (0.5, 0.55]
# ...                         ...          ...
# TTTGTGGCATAATCGT-1     0.454965  (0.45, 0.5]
# TTTGTGGCATTTGCTC-1     0.598991  (0.55, 0.6]
# TTTGTGTTCAATGACC-1     0.291581  (0.25, 0.3]
# TTTGTTGGTGGAGCAA-1     0.776289  (0.75, 0.8]
# TTTGTTGGTTAGAGCC-1     0.719392  (0.7, 0.75]
#
# [3365 rows x 8 columns]

# %%
binned_time = df_meta.binned.unique()

# %%
## add time labels
name_dict = {}
i = 0
for time in sorted(binned_time):
    name_dict[time] = i
    i += 1
name_dict
# Out:
# {'(-0.001, 0.05]': 0,
#  '(0.05, 0.1]': 1,
#  '(0.1, 0.15]': 2,
#  '(0.15, 0.2]': 3,
#  '(0.2, 0.25]': 4,
#  '(0.25, 0.3]': 5,
#  '(0.3, 0.35]': 6,
#  '(0.35, 0.4]': 7,
#  '(0.4, 0.45]': 8,
#  '(0.45, 0.5]': 9,
#  '(0.5, 0.55]': 10,
#  '(0.55, 0.6]': 11,
#  '(0.6, 0.65]': 12,
#  '(0.65, 0.7]': 13,
#  '(0.7, 0.75]': 14,
#  '(0.75, 0.8]': 15,
#  '(0.8, 0.85]': 16,
#  '(0.85, 0.9]': 17,
#  '(0.9, 0.95]': 18,
#  '(0.95, 1.0]': 19}

# %%
df_meta.apply(lambda row: name_dict[row.binned],axis=1)
# Out:
# AAACAGCCAACCGCCA-1    12
# AAACAGCCAAGGTCGA-1     5
# AAACAGCCAGGAACAT-1    17
# AAACAGCCATATTGAC-1    19
# AAACAGCCATGGTTAT-1    10
#                       ..
# TTTGTGGCATAATCGT-1     9
# TTTGTGGCATTTGCTC-1    11
# TTTGTGTTCAATGACC-1     5
# TTTGTTGGTGGAGCAA-1    15
# TTTGTTGGTTAGAGCC-1    14
# Length: 3365, dtype: int64

# %%
df_meta['time_label'] = df_meta.apply(lambda row: name_dict[row.binned], axis=1)
df_meta.head()
# Out:
#                     n_counts        celltype  velo_s_norm_self_transition  \
# AAACAGCCAACCGCCA-1     681.0     Upper Layer                     0.057197
# AAACAGCCAAGGTCGA-1     296.0  RG, Astro, OPC                     0.114116
# AAACAGCCAGGAACAT-1     504.0    Deeper Layer                     0.082940
# AAACAGCCATATTGAC-1     321.0    Deeper Layer                     0.106146
# AAACAGCCATGGTTAT-1     432.0        Subplate                     0.103904
#
#                     root_cells  end_points  velo_s_norm_pseudotime  \
# AAACAGCCAACCGCCA-1    0.037962    0.086987                0.857504
# AAACAGCCAAGGTCGA-1    0.049274    0.396248                0.213945
# AAACAGCCAGGAACAT-1    0.020133    0.338813                0.958743
# AAACAGCCATATTGAC-1    0.003566    0.735495                0.981135
# AAACAGCCATGGTTAT-1    0.036739    0.134693                0.848509
#
#                     latent_time       binned  time_label
# AAACAGCCAACCGCCA-1     0.604954  (0.6, 0.65]          12
# AAACAGCCAAGGTCGA-1     0.281341  (0.25, 0.3]           5
# AAACAGCCAGGAACAT-1     0.851495  (0.85, 0.9]          17
# AAACAGCCATATTGAC-1     0.982605  (0.95, 1.0]          19
# AAACAGCCATGGTTAT-1     0.549869  (0.5, 0.55]          10

# %%
name = np.array(df_meta.index)
newname = [n+"_paired" for n in name]
newname
# Out:
# ['AAACAGCCAACCGCCA-1_paired',
#  'AAACAGCCAAGGTCGA-1_paired',
#  'AAACAGCCAGGAACAT-1_paired',
#  'AAACAGCCATATTGAC-1_paired',
#  'AAACAGCCATGGTTAT-1_paired',
#  'AAACATGCACTTACAG-1_paired',
#  'AAACCAACAACTGGGA-1_paired',
#  'AAACCGCGTCACCAAA-1_paired',
#  'AAACCGCGTGCAATGC-1_paired',
#  'AAACCGGCAACTAACT-1_paired',
#  'AAACCGGCAATTAGGA-1_paired',
#  'AAACGCGCAGCTAATT-1_paired',
#  'AAACGCGCAGTTATCG-1_paired',
#  'AAACGCGCATCACTTC-1_paired',
#  'AAACGTACAAGGCCAA-1_paired',
#  'AAACGTACATCCTGAA-1_paired',
#  'AAACGTACATGTGGGA-1_paired',
#  'AAAGCAAGTGAGGTAG-1_paired',
#  'AAAGCAAGTTGCTGGG-1_paired',
#  'AAAGCACCAACTGGCT-1_paired',
#  'AAAGCCCGTATGGTGC-1_paired',
#  'AAAGCCCGTTCACCAT-1_paired',
#  'AAAGCCGCACAACCTA-1_paired',
#  'AAAGCCGCAGGCAAGC-1_paired',
#  'AAAGCCGCATCCGTAA-1_paired',
#  'AAAGCTTGTCATGCCC-1_paired',
#  'AAAGGAGCAATTTAGC-1_paired',
#  'AAAGGCTCAAATATCC-1_paired',
#  'AAAGGCTCAAGGTACG-1_paired',
#  'AAAGGCTCAATATACC-1_paired',
#  'AAAGGCTCAATCCCTT-1_paired',
#  'AAAGGCTCACCTGGTG-1_paired',
#  'AAAGGCTCATAGCGGA-1_paired',
#  'AAAGGCTCATTGGGAG-1_paired',
#  'AAAGGTTAGCTTACTT-1_paired',
#  'AAAGGTTAGTTGCGTG-1_paired',
#  'AAAGGTTAGTTTGAGC-1_paired',
#  'AAATGCCTCATAATCG-1_paired',
#  'AAATGCCTCGATTCTT-1_paired',
#  'AACAGATAGAGGAGTC-1_paired',
#  'AACAGCAAGTTAGTGC-1_paired',
#  'AACAGCAAGTTATCCT-1_paired',
#  'AACAGGATCAATGTGC-1_paired',
#  'AACAGGATCGATTTAG-1_paired',
#  'AACATAGCAACCCTAA-1_paired',
#  'AACATAGCACCTGGTG-1_paired',
#  'AACATAGCATAAACCT-1_paired',
#  'AACATTGTCACCTGTC-1_paired',
#  'AACATTGTCCCGCATT-1_paired',
#  'AACATTGTCGATTCTT-1_paired',
#  'AACCCGCAGGCCAATT-1_paired',
#  'AACCGCTCAATAATCC-1_paired',
#  'AACCGCTCAATCCCTT-1_paired',
#  'AACCGCTCACCTAAGC-1_paired',
#  'AACCTCACAGGTTCAC-1_paired',
#  'AACCTCCTCAGGTCCA-1_paired',
#  'AACCTCCTCGGGCCAT-1_paired',
#  'AACCTCCTCTCGCCCA-1_paired',
#  'AACCTTAAGGGCTAAA-1_paired',
#  'AACCTTAAGTAACAGG-1_paired',
#  'AACCTTGCAGCGCTTG-1_paired',
#  'AACGACAAGCATGTTA-1_paired',
#  'AACGACAAGTAAGTCC-1_paired',
#  'AACGACAAGTCACGAT-1_paired',
#  'AACGCCCAGCACTAGT-1_paired',
#  'AACGCCCAGGACAATG-1_paired',
#  'AACGCTAGTCAGGCCA-1_paired',
#  'AACTACTCAAACGGGC-1_paired',
#  'AACTACTCAGCCTGCA-1_paired',
#  'AACTACTCAGCTCATA-1_paired',
#  'AACTAGCTCAATGTGC-1_paired',
#  'AACTAGCTCAGCACGC-1_paired',
#  'AACTAGCTCGCGACAC-1_paired',
#  'AACTCACAGATGGAGC-1_paired',
#  'AACTCACAGTCATTGA-1_paired',
#  'AACTCACAGTTTGCGG-1_paired',
#  'AACTGTTCACTTAGGC-1_paired',
#  'AACTGTTCATAATCGT-1_paired',
#  'AACTTAGTCACAAGCT-1_paired',
#  'AACTTAGTCATTTGTC-1_paired',
#  'AACTTAGTCCCGCATT-1_paired',
#  'AAGAATCAGGCTAAGA-1_paired',
#  'AAGAATCAGTGTTGTA-1_paired',
#  'AAGACATAGGACTTAC-1_paired',
#  'AAGACATAGGCATGTT-1_paired',
#  'AAGACATAGGCTGTCA-1_paired',
#  'AAGACATAGTTACCGG-1_paired',
#  'AAGACCAAGCACTAAC-1_paired',
#  'AAGACCAAGCAGGCCT-1_paired',
#  'AAGACCAAGCGAAGTA-1_paired',
#  'AAGCAAGTCGCTAGTG-1_paired',
#  'AAGCAAGTCTGTTCAT-1_paired',
#  'AAGCATGAGGTCCTGA-1_paired',
#  'AAGCCACGTGTTGCTT-1_paired',
#  'AAGCCACGTTTGTGGA-1_paired',
#  'AAGCCTCCATGTCAGC-1_paired',
#  'AAGCCTGTCATGGTTA-1_paired',
#  'AAGCCTGTCCTAGTCC-1_paired',
#  'AAGCCTTAGTAAGTGG-1_paired',
#  'AAGCGAATCCCTGGTT-1_paired',
#  'AAGCGAATCGACAAAG-1_paired',
#  'AAGCGAGGTGTTGCTT-1_paired',
#  'AAGCGAGGTTCGGTAA-1_paired',
#  'AAGCGGGTCCAGGTCA-1_paired',
#  'AAGCGGGTCCCATAGG-1_paired',
#  'AAGCGTTTCTAAGGAG-1_paired',
#  'AAGCGTTTCTTGTTCG-1_paired',
#  'AAGCTAGAGGCCTAAT-1_paired',
#  'AAGCTAGAGGGACCTC-1_paired',
#  'AAGCTAGAGGTTACGT-1_paired',
#  'AAGCTATGTGTCCTGC-1_paired',
#  'AAGCTATGTTACATCC-1_paired',
#  'AAGCTTGGTAACGTGC-1_paired',
#  'AAGCTTGGTCAATACG-1_paired',
#  'AAGCTTGGTGTTTGTC-1_paired',
#  'AAGCTTGGTTTGCAGA-1_paired',
#  'AAGGAAGCAGGCTTCG-1_paired',
#  'AAGGATGTCCGGCTAA-1_paired',
#  'AAGGATTAGGTTAGAG-1_paired',
#  'AAGGATTAGTAGCGGG-1_paired',
#  'AAGGCCCTCTCTAGCC-1_paired',
#  'AAGGTATAGGACACTT-1_paired',
#  'AAGGTATAGGTTACGT-1_paired',
#  'AAGGTCAAGGCTTAAC-1_paired',
#  'AAGGTGCAGGAGGTTA-1_paired',
#  'AAGTAGCCAGCTCATA-1_paired',
#  'AAGTCTATCCAGCACA-1_paired',
#  'AAGTGAAGTGATCATG-1_paired',
#  'AAGTGCAAGAATCGCT-1_paired',
#  'AAGTGCAAGGGTCCAC-1_paired',
#  'AAGTGCAAGTCATTGA-1_paired',
#  'AAGTGTTGTACCCACC-1_paired',
#  'AAGTGTTGTATTGGTG-1_paired',
#  'AAGTGTTGTTTGCTGT-1_paired',
#  'AAGTTACGTATTGCAG-1_paired',
#  'AAGTTACGTCCTAAGA-1_paired',
#  'AAGTTACGTGTAACCA-1_paired',
#  'AAGTTAGCAATAATCC-1_paired',
#  'AAGTTAGCAGGTCCTG-1_paired',
#  'AAGTTTGTCAAATCGC-1_paired',
#  'AAGTTTGTCATTACAG-1_paired',
#  'AATAACCGTAAGCTCA-1_paired',
#  'AATAACCGTCCACAAA-1_paired',
#  'AATAACCGTGTGAGGA-1_paired',
#  'AATAACCGTTACTAGG-1_paired',
#  'AATAGAGGTCGTAAAT-1_paired',
#  'AATAGAGGTGCATCGG-1_paired',
#  'AATAGCTGTGATGATT-1_paired',
#  'AATAGCTGTTGCTGGG-1_paired',
#  'AATATCCCAACCTGGT-1_paired',
#  'AATATCCCAATTGCGC-1_paired',
#  'AATATCCCACACTAAT-1_paired',
#  'AATATCCCAGCAAATA-1_paired',
#  'AATCATCCACAAAGGT-1_paired',
#  'AATCATCCAGTTATCG-1_paired',
#  'AATCATCCATCCCGCT-1_paired',
#  'AATCCATCAGGCTACT-1_paired',
#  'AATCCCTGTTTGCTGT-1_paired',
#  'AATCCGTAGAAGCTAG-1_paired',
#  'AATCCGTAGTATTGCA-1_paired',
#  'AATCCGTAGTTAGCCG-1_paired',
#  'AATCCTAAGCAAGGTA-1_paired',
#  'AATCGCCCAGATAGAC-1_paired',
#  'AATCGCCCATAAGGAC-1_paired',
#  'AATCTTGAGGTAGCTT-1_paired',
#  'AATGCATGTCAGGCAT-1_paired',
#  'AATGCATGTGATCAGC-1_paired',
#  'AATGCATGTTGGTTCT-1_paired',
#  'AATGCATGTTGTTGTC-1_paired',
#  'AATGCGCGTTACGCGG-1_paired',
#  'AATGGCGCACATAGCC-1_paired',
#  'AATGGCGCAGGCATCT-1_paired',
#  'AATGGCGCAGGCTAGA-1_paired',
#  'AATGTCATCCTGCGAA-1_paired',
#  'AATGTCATCGGTTTGG-1_paired',
#  'AATGTCATCTCACACC-1_paired',
#  'AATGTCCAGAACCTGT-1_paired',
#  'AATGTCCAGATAAAGC-1_paired',
#  'AATGTCCAGGGATGCG-1_paired',
#  'AATGTCCAGTGCACGC-1_paired',
#  'AATGTCCAGTTAGCTA-1_paired',
#  'AATTAGGCACAAAGAC-1_paired',
#  'AATTAGGCATTATGGT-1_paired',
#  'AATTGACGTTACTAGG-1_paired',
#  'AATTGCCAGCCTGATG-1_paired',
#  'AATTGCCAGTATCGCG-1_paired',
#  'AATTGCCAGTTTGAGC-1_paired',
#  'AATTGCTCACAGCCTG-1_paired',
#  'AATTGCTCACGTAAGG-1_paired',
#  'AATTGCTCAGTCTAGC-1_paired',
#  'AATTGTGTCAAATCGC-1_paired',
#  'AATTGTGTCACGTTAA-1_paired',
#  'AATTGTGTCGCTTCTA-1_paired',
#  'AATTTGGTCCTGCGAA-1_paired',
#  'ACAAACTGTTCTTTAG-1_paired',
#  'ACAAACTGTTGCAATG-1_paired',
#  'ACAAAGGTCACCGGTA-1_paired',
#  'ACAAAGGTCTTGCAGG-1_paired',
#  'ACAACAACAATCTCTC-1_paired',
#  'ACAACAACAATTTAGC-1_paired',
#  'ACAACAACAGAATGAC-1_paired',
#  'ACAACATGTACCGGAT-1_paired',
#  'ACAACATGTGCTGGTG-1_paired',
#  'ACAACATGTGTTGCAA-1_paired',
#  'ACAACATGTGTTGTGA-1_paired',
#  'ACACCTTGTGTTGCAA-1_paired',
#  'ACACCTTGTTTATGGG-1_paired',
#  'ACACGGACAAACCTTG-1_paired',
#  'ACACTAATCATGCGTG-1_paired',
#  'ACACTAATCCATCAGG-1_paired',
#  'ACACTAATCGCATTAA-1_paired',
#  'ACACTAGGTCAAACTG-1_paired',
#  'ACACTAGGTTAGAGCC-1_paired',
#  'ACACTTAAGTAATCCA-1_paired',
#  'ACACTTAAGTTGTCTT-1_paired',
#  'ACACTTGCAAGTAAGC-1_paired',
#  'ACACTTGCAATAAGCA-1_paired',
#  'ACACTTGCAGCAAGTG-1_paired',
#  'ACAGCGCTCAATGTGC-1_paired',
#  'ACAGCGCTCCCGAACA-1_paired',
#  'ACAGCGCTCGGTTACG-1_paired',
#  'ACAGCGCTCTGTGAGT-1_paired',
#  'ACAGGAATCATGAAGG-1_paired',
#  'ACAGGAATCTTGGACG-1_paired',
#  'ACAGGATCACTGGCTG-1_paired',
#  'ACAGGATCAGACAAAC-1_paired',
#  'ACAGGATCAGGCTAGA-1_paired',
#  'ACAGGATCATCATGTG-1_paired',
#  'ACAGTATGTTGGATAT-1_paired',
#  'ACATAGCTCGGTTTGG-1_paired',
#  'ACATCAATCCCTCATA-1_paired',
#  'ACATCAATCCGGTTGA-1_paired',
#  'ACATCAATCGAGCAAA-1_paired',
#  'ACATCAATCGGTACGC-1_paired',
#  'ACATCAATCTTAGCGG-1_paired',
#  'ACATCATCAACAGGTG-1_paired',
#  'ACATCATCAGTAAAGC-1_paired',
#  'ACATTAGTCAGTGAAG-1_paired',
#  'ACATTGCAGATTGAGG-1_paired',
#  'ACATTGCAGTCAATCA-1_paired',
#  'ACCAAACTCCTCACAC-1_paired',
#  'ACCAAACTCTCACTAT-1_paired',
#  'ACCAAGCGTAAAGCGG-1_paired',
#  'ACCAAGCGTCCAAATG-1_paired',
#  'ACCAAGCGTGCCGCAA-1_paired',
#  'ACCAAGCGTTGACTTC-1_paired',
#  'ACCAAGCGTTGTTGCT-1_paired',
#  'ACCAAGCGTTTGGCTT-1_paired',
#  'ACCAAGTTCCAAGTTA-1_paired',
#  'ACCAAGTTCTTCAATC-1_paired',
#  'ACCAATATCGATTTGA-1_paired',
#  'ACCAATATCGGTTACG-1_paired',
#  'ACCACACCATCACAGC-1_paired',
#  'ACCACATAGCGAGGTG-1_paired',
#  'ACCAGCTCACCCTCAC-1_paired',
#  'ACCAGCTCAGGCTTGT-1_paired',
#  'ACCAGGACACCTCAGG-1_paired',
#  'ACCAGGACAGAAACGT-1_paired',
#  'ACCAGGACAGGCGATA-1_paired',
#  'ACCAGGCTCATGCTCC-1_paired',
#  'ACCAGGCTCTTGAGGT-1_paired',
#  'ACCAGGGAGACAACGA-1_paired',
#  'ACCAGGGAGCAATAGG-1_paired',
#  'ACCAGGGAGGAAACTG-1_paired',
#  'ACCATAATCCAGCACA-1_paired',
#  'ACCATTAAGCACAGAA-1_paired',
#  'ACCATTAAGCCGCAAC-1_paired',
#  'ACCATTAAGGTCAAAG-1_paired',
#  'ACCATTAAGTAAGTGG-1_paired',
#  'ACCCAACCAACCTAAT-1_paired',
#  'ACCCAACCATTAAACC-1_paired',
#  'ACCCAGGGTGTAACCA-1_paired',
#  'ACCCGCTGTTCCATTA-1_paired',
#  'ACCCGGTAGATAAAGC-1_paired',
#  'ACCCGGTAGCCTGATG-1_paired',
#  'ACCCGGTAGCTTACTT-1_paired',
#  'ACCCGGTAGGACTTAC-1_paired',
#  'ACCCGGTAGTAGAGGC-1_paired',
#  'ACCCTCCCAATAATCC-1_paired',
#  'ACCCTGTTCAATGTGC-1_paired',
#  'ACCCTGTTCAGGAACA-1_paired',
#  'ACCGAAGCATGCAACC-1_paired',
#  'ACCGAAGCATTGACAT-1_paired',
#  'ACCGCAATCGATTATG-1_paired',
#  'ACCGGCTAGCGCTCAA-1_paired',
#  'ACCGGCTAGGCCGGAA-1_paired',
#  'ACCGGCTAGGTACCGC-1_paired',
#  'ACCGGTTCAAGATTCT-1_paired',
#  'ACCGGTTCATTAAAGG-1_paired',
#  'ACCTAAATCAGCAAAG-1_paired',
#  'ACCTAAATCGAGGAGT-1_paired',
#  'ACCTAAGGTCCTTTAA-1_paired',
#  'ACCTACCTCACCTGTC-1_paired',
#  'ACCTACCTCACGAATC-1_paired',
#  'ACCTACCTCCACCTGT-1_paired',
#  'ACCTACCTCGCAAACT-1_paired',
#  'ACCTCACTCCAAGTGT-1_paired',
#  'ACCTCACTCTGGCAAT-1_paired',
#  'ACCTGGATCACCGGTA-1_paired',
#  'ACCTGGATCCTCATCA-1_paired',
#  'ACCTGGTCAAACCTTG-1_paired',
#  'ACCTGGTCAACCCTCC-1_paired',
#  'ACCTGGTCAGTAGCCT-1_paired',
#  'ACCTGTTGTACCAGGT-1_paired',
#  'ACCTGTTGTTCACCAT-1_paired',
#  'ACCTGTTGTTGGCGTG-1_paired',
#  'ACCTTCATCGTTAGTA-1_paired',
#  'ACCTTCCAGCTAATCA-1_paired',
#  'ACCTTCCAGGATTTGC-1_paired',
#  'ACCTTGTGTATTGCAG-1_paired',
#  'ACCTTGTGTGTCACGG-1_paired',
#  'ACGAACAAGCGCCTTT-1_paired',
#  'ACGAACAAGGTTACGT-1_paired',
#  'ACGAACAAGTTATGTG-1_paired',
#  'ACGAAGTCAAGCTTAT-1_paired',
#  'ACGAAGTCACCCACCT-1_paired',
#  'ACGAAGTCAGGACCAA-1_paired',
#  'ACGAAGTCAGGTTCAC-1_paired',
#  'ACGAATCTCCCGCATT-1_paired',
#  'ACGAGTAAGGAAGCTA-1_paired',
#  'ACGAGTAAGTGTGATC-1_paired',
#  'ACGCAAGCAATAACGA-1_paired',
#  'ACGCAAGCAGTTTGGC-1_paired',
#  'ACGCAAGCATGTTGGC-1_paired',
#  'ACGCACGGTAACCACA-1_paired',
#  'ACGCACGGTATTGTCC-1_paired',
#  'ACGCACGGTGCCTCAC-1_paired',
#  'ACGCACGGTTATCCTA-1_paired',
#  'ACGCCACAGAAGGTGC-1_paired',
#  'ACGCCACAGAGGGACT-1_paired',
#  'ACGCCACAGGCTTAGT-1_paired',
#  'ACGCCACAGGTCCACA-1_paired',
#  'ACGCCTAAGTTAGCCG-1_paired',
#  'ACGCTTGAGTTCCCAC-1_paired',
#  'ACGGTACGTGATTTGG-1_paired',
#  'ACGGTTAGTATGGTGC-1_paired',
#  'ACGGTTAGTTAACGGC-1_paired',
#  'ACGGTTAGTTGTAAAC-1_paired',
#  'ACGGTTTAGCGCTCAA-1_paired',
#  'ACGGTTTAGGAACCGG-1_paired',
#  'ACGTACCCAAACTGTT-1_paired',
#  'ACGTACCCAACCGCCA-1_paired',
#  'ACGTCAAGTACAAAGA-1_paired',
#  'ACGTCAAGTGGCTTCC-1_paired',
#  'ACGTCAAGTGTTTCAC-1_paired',
#  'ACGTCAAGTTACGCGG-1_paired',
#  'ACGTCCTTCACTAATG-1_paired',
#  'ACGTCCTTCAGCAAGA-1_paired',
#  'ACGTTACAGGCCATCA-1_paired',
#  'ACGTTACAGGCCTAAT-1_paired',
#  'ACGTTGTAGCACTAAC-1_paired',
#  'ACGTTGTAGCACTTGG-1_paired',
#  'ACGTTGTAGGAGGGTT-1_paired',
#  'ACGTTGTAGTAACGGA-1_paired',
#  'ACTAAAGCAAACTCAT-1_paired',
#  'ACTAAAGCAGTTAAAG-1_paired',
#  'ACTAACCAGCCACAAT-1_paired',
#  'ACTAACCAGCTTAACA-1_paired',
#  'ACTAACTCAAGTGAAC-1_paired',
#  'ACTAACTCACCAAAGG-1_paired',
#  'ACTAACTCACCCACAG-1_paired',
#  'ACTAACTCAGCATGGA-1_paired',
#  'ACTAACTCAGGAACAT-1_paired',
#  'ACTAACTCATTGCGGT-1_paired',
#  'ACTAACTCATTGTGGC-1_paired',
#  'ACTAATCCAGTTTCTC-1_paired',
#  'ACTAATCCATGTTTGG-1_paired',
#  'ACTAGGCGTCCTCCAA-1_paired',
#  'ACTAGGCGTTTGGTTC-1_paired',
#  'ACTATCCGTATCTGGA-1_paired',
#  'ACTATCCGTCATGAGC-1_paired',
#  'ACTATCCGTCGTAAAT-1_paired',
#  'ACTATGTCAGGACCTT-1_paired',
#  'ACTATGTCATGAGCAG-1_paired',
#  'ACTCACCTCACGCGGT-1_paired',
#  'ACTCACCTCATTGCAA-1_paired',
#  'ACTCACTGTGGTTATG-1_paired',
#  'ACTCACTGTTATCCTA-1_paired',
#  'ACTCAGTAGCAAGATG-1_paired',
#  'ACTCAGTAGCCAGGTC-1_paired',
#  'ACTCAGTAGCCGCTTT-1_paired',
#  'ACTCAGTAGGATCACT-1_paired',
#  'ACTCAGTAGTTACTTC-1_paired',
#  'ACTCCTCAGGCCCAGT-1_paired',
#  'ACTCCTCAGTATTGCA-1_paired',
#  'ACTCGCGCAACCCTAA-1_paired',
#  'ACTCGCGCAGTGAACG-1_paired',
#  'ACTCGCGCAGTTTACG-1_paired',
#  'ACTCGCGCATAGCGAG-1_paired',
#  'ACTCGCTTCAAACTCA-1_paired',
#  'ACTCGCTTCAGGCCTA-1_paired',
#  'ACTCGCTTCCTTCTAG-1_paired',
#  'ACTCGCTTCGACAAAG-1_paired',
#  'ACTCGCTTCTTTGAGA-1_paired',
#  'ACTGAAACAACACCTA-1_paired',
#  'ACTGAATGTCACAAAT-1_paired',
#  'ACTGAATGTGATTACG-1_paired',
#  'ACTGAATGTTAATCGG-1_paired',
#  'ACTGAATGTTAGCAGC-1_paired',
#  'ACTTACTTCCACCTGT-1_paired',
#  'ACTTACTTCGCTCACT-1_paired',
#  'ACTTAGGGTAACGGGA-1_paired',
#  'ACTTAGGGTAATCGTG-1_paired',
#  'ACTTAGGGTGATTACG-1_paired',
#  'ACTTAGTCAAGGGTTG-1_paired',
#  'ACTTAGTCACCTATAG-1_paired',
#  'ACTTAGTCATCATGTG-1_paired',
#  'ACTTAGTCATGATTGT-1_paired',
#  'ACTTAGTCATTTGCTC-1_paired',
#  'ACTTATCTCGCGCTAA-1_paired',
#  'ACTTATCTCGGTTCCT-1_paired',
#  'ACTTATCTCTAACCTT-1_paired',
#  'ACTTATCTCTCACTAT-1_paired',
#  'ACTTATGAGCGAGTAA-1_paired',
#  'ACTTATGAGTCACCTC-1_paired',
#  'ACTTATGAGTTGCGTG-1_paired',
#  'ACTTGAATCGGGCCAT-1_paired',
#  'ACTTGCACAACCTGGT-1_paired',
#  'ACTTGTAAGCGGATTT-1_paired',
#  'ACTTGTAAGTGTGATC-1_paired',
#  'ACTTTGTTCCACCCTG-1_paired',
#  'AGAAACTAGGACGTAA-1_paired',
#  'AGAAAGGCAGTTTCTC-1_paired',
#  'AGAACAAGTGACCTGG-1_paired',
#  'AGAACAAGTGATCATG-1_paired',
#  'AGAACAAGTTCGCTTG-1_paired',
#  'AGAACCAAGCAGGCCT-1_paired',
#  'AGAACCGCAAGTTATC-1_paired',
#  'AGAACCGCATTAGCCA-1_paired',
#  'AGAAGGTGTGCTTAGA-1_paired',
#  'AGAAGGTGTGGTTATG-1_paired',
#  'AGAAGGTGTGTTTGTC-1_paired',
#  'AGAAGGTGTTAATGAC-1_paired',
#  'AGAATCGAGCTCATAA-1_paired',
#  'AGAATCGAGTTAACCA-1_paired',
#  'AGAATCTGTGTGTGGT-1_paired',
#  'AGACAATAGCATCCAG-1_paired',
#  'AGACAATAGGTAAGCA-1_paired',
#  'AGACAATAGTTCCCAC-1_paired',
#  'AGACACGCAAGCTACC-1_paired',
#  'AGACACGCACAGCCTG-1_paired',
#  'AGACACGCATGGTTAT-1_paired',
#  'AGACCCGGTAGGTGTC-1_paired',
#  'AGACCCGGTTACTTGC-1_paired',
#  'AGAGAAGCACCAGGTT-1_paired',
#  'AGAGAAGCACCTCGCT-1_paired',
#  'AGAGAAGCATTGTCAG-1_paired',
#  'AGAGAGGAGCAACAAG-1_paired',
#  'AGAGAGGAGTAGGATG-1_paired',
#  'AGAGGAACAGGCCATT-1_paired',
#  'AGAGGAACATAGACCC-1_paired',
#  'AGAGGATGTGATGGCT-1_paired',
#  'AGATGAAGTGCAATAT-1_paired',
#  'AGATGAAGTTACCGGG-1_paired',
#  'AGATGAAGTTAGGTTG-1_paired',
#  'AGATGCTTCCACAATA-1_paired',
#  'AGATGCTTCCGGCTAA-1_paired',
#  'AGATGCTTCTAAGGTC-1_paired',
#  'AGATGCTTCTTGCAAA-1_paired',
#  'AGCAAATAGAGCAAGC-1_paired',
#  'AGCAAATAGCCAGGTC-1_paired',
#  'AGCAACAAGCTGGACC-1_paired',
#  'AGCAACAAGGAGCACG-1_paired',
#  'AGCAAGGGTCAAGACC-1_paired',
#  'AGCAATACAATCATGT-1_paired',
#  'AGCAATACAGGCTACT-1_paired',
#  'AGCAATACAGTTTGGC-1_paired',
#  'AGCAATTGTTTGGCGG-1_paired',
#  'AGCACAGCAGGATTAA-1_paired',
#  'AGCACAGCATGCTCCC-1_paired',
#  'AGCACTAGTCACCTAT-1_paired',
#  'AGCACTAGTCGTTACT-1_paired',
#  'AGCACTAGTTGTTGCT-1_paired',
#  'AGCACTTAGAGGAGGA-1_paired',
#  'AGCACTTAGGAGGGTT-1_paired',
#  'AGCAGGTAGCTGTCAG-1_paired',
#  'AGCAGGTAGTTGGGCC-1_paired',
#  'AGCATCCCAAGGTCCT-1_paired',
#  'AGCATCCCAGCAAGTG-1_paired',
#  'AGCATCCCAGGGAGGA-1_paired',
#  'AGCATTTCAGGCTTGT-1_paired',
#  'AGCCAGTGTTAACGGC-1_paired',
#  'AGCCGCTAGGTAACGA-1_paired',
#  'AGCCGCTAGTTTAACG-1_paired',
#  'AGCCGGTTCGATTTGA-1_paired',
#  'AGCCGGTTCGGTACGC-1_paired',
#  'AGCCGGTTCTGGCAAT-1_paired',
#  'AGCCTAAGTAAGTCGC-1_paired',
#  'AGCCTAGTCGAGGAAC-1_paired',
#  'AGCCTCCGTTAATCGG-1_paired',
#  'AGCCTCCGTTTCGCCA-1_paired',
#  'AGCCTGGGTCTAGCTT-1_paired',
#  'AGCCTGGGTTAGGACC-1_paired',
#  'AGCCTGGGTTTGGGCG-1_paired',
#  'AGCGATTTCAAACCGT-1_paired',
#  'AGCGCCTAGTCGCTAG-1_paired',
#  'AGCGCTCAGGCTACAT-1_paired',
#  'AGCGCTCAGGCTATGT-1_paired',
#  'AGCGGACCAGAGGCTA-1_paired',
#  'AGCGGATAGAAAGGAA-1_paired',
#  'AGCGGATAGTAACCCG-1_paired',
#  'AGCGGATAGTTATCCT-1_paired',
#  'AGCGTGCTCCTAAATG-1_paired',
#  'AGCGTGCTCGGTTTCC-1_paired',
#  'AGCTAAACAGCTAATT-1_paired',
#  'AGCTAACTCCTGGCTT-1_paired',
#  'AGCTAACTCGGGATTT-1_paired',
#  'AGCTACGTCATTAGTG-1_paired',
#  'AGCTACGTCATTGCAA-1_paired',
#  'AGCTACGTCCCGTTTA-1_paired',
#  'AGCTACGTCGTAATCA-1_paired',
#  'AGCTACTAGTAGAGGC-1_paired',
#  'AGCTAGTTCAGCATTA-1_paired',
#  'AGCTAGTTCCTAGTAA-1_paired',
#  'AGCTATATCACTAGGT-1_paired',
#  'AGCTATATCATTCATC-1_paired',
#  'AGCTATATCCCTGGAA-1_paired',
#  'AGCTCATAGCGTGCGT-1_paired',
#  'AGCTCATAGCTTTGTT-1_paired',
#  'AGCTCATAGTCAATCA-1_paired',
#  'AGCTGCTCAAATGCCC-1_paired',
#  'AGCTGCTCATAGCGAG-1_paired',
#  'AGCTTAATCCCTGATC-1_paired',
#  'AGCTTAATCGGTTAGT-1_paired',
#  'AGCTTAATCTTGACCC-1_paired',
#  'AGCTTCCTCCCGTTGT-1_paired',
#  'AGCTTCCTCGTTCACC-1_paired',
#  'AGCTTTAAGACACCGC-1_paired',
#  'AGCTTTAAGACCATAC-1_paired',
#  'AGCTTTAAGGCTAAGA-1_paired',
#  'AGCTTTAAGTTGGGCC-1_paired',
#  'AGGAAACGTGGATTAT-1_paired',
#  'AGGAACCAGGTAAGCA-1_paired',
#  'AGGAACGGTCTTTGAC-1_paired',
#  'AGGACGTAGGACCAGG-1_paired',
#  'AGGACGTAGTAACTCA-1_paired',
#  'AGGACTAAGCACTAAC-1_paired',
#  'AGGACTAAGGAGTAAT-1_paired',
#  'AGGAGCTAGGATCCGC-1_paired',
#  'AGGATATAGATGCCTG-1_paired',
#  'AGGATATAGGCGCTTA-1_paired',
#  'AGGATATAGGCTGGCT-1_paired',
#  'AGGATCCGTCAATGTG-1_paired',
#  'AGGATGCAGGCGTAAA-1_paired',
#  'AGGATGCAGGGCTTTG-1_paired',
#  'AGGATGTCAACTAACT-1_paired',
#  'AGGATGTCACAACCTA-1_paired',
#  'AGGATGTCAGGTATTT-1_paired',
#  'AGGATGTCATCATGTG-1_paired',
#  'AGGATTGAGGCAATAG-1_paired',
#  'AGGATTGAGTAACGAG-1_paired',
#  'AGGCAATCACCTACTT-1_paired',
#  'AGGCAATCACTAGCGT-1_paired',
#  'AGGCAATCAGGATGGC-1_paired',
#  'AGGCAATCAGGCGAGT-1_paired',
#  'AGGCAATCAGTTAAAG-1_paired',
#  'AGGCAATCATAATTGC-1_paired',
#  'AGGCAGGTCACTCGCT-1_paired',
#  'AGGCAGGTCCCATAGG-1_paired',
#  'AGGCAGGTCCCTCATA-1_paired',
#  'AGGCCCAGTACTGATG-1_paired',
#  'AGGCGGATCACTAAGC-1_paired',
#  'AGGCTAAAGGCGCATC-1_paired',
#  'AGGCTAAAGGGTGAAC-1_paired',
#  'AGGCTAGCACAACCTA-1_paired',
#  'AGGCTAGCACCTGTAA-1_paired',
#  'AGGCTAGCAGCATGAG-1_paired',
#  'AGGGCCTTCATGCTCC-1_paired',
#  'AGGGCTACAACACTTG-1_paired',
#  'AGGGCTACAAGGTCGA-1_paired',
#  'AGGGCTACAGCTTACA-1_paired',
#  'AGGGTTGCAATAATGG-1_paired',
#  'AGGGTTGCACAAAGAC-1_paired',
#  'AGGTACGCAAGCCACT-1_paired',
#  'AGGTATTGTCAAGACC-1_paired',
#  'AGGTATTGTCATTAGG-1_paired',
#  'AGGTATTGTTAGTACG-1_paired',
#  'AGGTCAAAGGTCCGTA-1_paired',
#  'AGGTCATTCTCACATT-1_paired',
#  'AGGTCCGGTAACTACG-1_paired',
#  'AGGTCTTAGGAGTCGG-1_paired',
#  'AGGTGAATCAAGTGTC-1_paired',
#  'AGGTGAATCATGTCAA-1_paired',
#  'AGGTGAATCATTACGA-1_paired',
#  'AGGTGAATCTCATCAT-1_paired',
#  'AGGTGAGGTGAGACTC-1_paired',
#  'AGGTTAACACAGCCTG-1_paired',
#  'AGGTTAACACTAGGTC-1_paired',
#  'AGGTTAACAGAAATTG-1_paired',
#  'AGGTTACTCATCCTGC-1_paired',
#  'AGGTTACTCTCCTCTT-1_paired',
#  'AGGTTAGAGCCGCTTT-1_paired',
#  'AGGTTAGAGTAAGTGG-1_paired',
#  'AGGTTAGAGTTACCGG-1_paired',
#  'AGGTTGCGTCATCATC-1_paired',
#  'AGGTTTGGTAGCTGGT-1_paired',
#  'AGGTTTGGTGTTGTGA-1_paired',
#  'AGTAACACACCTGCCT-1_paired',
#  'AGTAACACAGATTCAT-1_paired',
#  'AGTAACACAGGCTGTT-1_paired',
#  'AGTAACCTCAACAAGG-1_paired',
#  'AGTAACCTCAGCTAAC-1_paired',
#  'AGTAACCTCCCATAGG-1_paired',
#  'AGTAACCTCCCTCAGT-1_paired',
#  'AGTAATGCACGAATCC-1_paired',
#  'AGTACGCGTAGTAAGA-1_paired',
#  'AGTACGCGTCGCGCAA-1_paired',
#  'AGTAGGATCCCTCACG-1_paired',
#  'AGTCAAGAGACTCGCA-1_paired',
#  'AGTCCTGAGGGATGCG-1_paired',
#  'AGTCCTTGTAATCCCT-1_paired',
#  'AGTCCTTGTCGCGCAA-1_paired',
#  'AGTCCTTGTTTCGCGC-1_paired',
#  'AGTCGCATCCGTGACA-1_paired',
#  'AGTCGCATCGCTCACT-1_paired',
#  'AGTCGCATCGGTAACT-1_paired',
#  'AGTCTTGCATTGCGAC-1_paired',
#  'AGTGAGTCAATTGACT-1_paired',
#  'AGTGAGTCACTTGTTC-1_paired',
#  'AGTGAGTCAGGTTAAA-1_paired',
#  'AGTGATGAGCATTTCT-1_paired',
#  'AGTGATGAGGGACGCA-1_paired',
#  'AGTGCCGGTATTACCC-1_paired',
#  'AGTGCCGGTCCCGGAA-1_paired',
#  'AGTGCCGGTGTGAGAG-1_paired',
#  'AGTGCGGAGCTGAGGG-1_paired',
#  'AGTGGACAGATACTTG-1_paired',
#  'AGTGGACAGCGTGCAC-1_paired',
#  'AGTGGACAGGCTGTGC-1_paired',
#  'AGTGGACAGGTGTTAC-1_paired',
#  'AGTGGACAGTTGTCCC-1_paired',
#  'AGTGTGGCAACTAGAA-1_paired',
#  'AGTGTGGCAGGATTAA-1_paired',
#  'AGTGTTTCACCATATG-1_paired',
#  'AGTGTTTCATAATTGC-1_paired',
#  'AGTGTTTCATGTCAAT-1_paired',
#  'AGTTGCAGTTGGGTTA-1_paired',
#  'AGTTGCGTCGCAATCG-1_paired',
#  'AGTTGGCGTAGCAGCT-1_paired',
#  'AGTTGGCGTTCACCAT-1_paired',
#  'AGTTTGATCCTGAATA-1_paired',
#  'AGTTTGCAGACAGGTA-1_paired',
#  'AGTTTGCAGCATGTCG-1_paired',
#  'AGTTTGCAGTCAGTAC-1_paired',
#  'AGTTTGCAGTTCCTCA-1_paired',
#  'ATAACGACACAATTAC-1_paired',
#  'ATAACGACACTCGCTC-1_paired',
#  'ATAACGACAGGATGGC-1_paired',
#  'ATAACGACATAATCAC-1_paired',
#  'ATAACGACATGCTATG-1_paired',
#  'ATAACGACATTAGGTT-1_paired',
#  'ATAAGCCTCGAGCTAT-1_paired',
#  'ATAAGCCTCGCTCCAT-1_paired',
#  'ATAAGCCTCTAAGGAG-1_paired',
#  'ATAAGCCTCTCCTCTT-1_paired',
#  'ATAAGCCTCTGTTCAT-1_paired',
#  'ATAATGGCACAGGGAC-1_paired',
#  'ATACCGGTCGGTTAGT-1_paired',
#  'ATACCGGTCTCACTAT-1_paired',
#  'ATACCTGCAATCCTAG-1_paired',
#  'ATACCTGCAGGAACTG-1_paired',
#  'ATACCTGCATCATGTG-1_paired',
#  'ATACCTGCATGGCCCA-1_paired',
#  'ATAGATGCATTAAGTC-1_paired',
#  'ATAGGTACAAAGCTCC-1_paired',
#  'ATATGCATCTAGCGTG-1_paired',
#  'ATATGCATCTTGAGGT-1_paired',
#  'ATATGCTCAGCTTAGC-1_paired',
#  'ATATGCTCATCCATCT-1_paired',
#  'ATATGGTGTTTGGCTT-1_paired',
#  'ATATGTCCAATTAACC-1_paired',
#  'ATATGTCCAGCTTAGC-1_paired',
#  'ATCAAGACAGCAAGTG-1_paired',
#  'ATCAATCCAGCTAATT-1_paired',
#  'ATCACACAGAAGGTGC-1_paired',
#  'ATCACACAGCACCACA-1_paired',
#  'ATCACACAGGGATGCG-1_paired',
#  'ATCACCCTCATGTCAA-1_paired',
#  'ATCACCCTCCTGCGAA-1_paired',
#  'ATCACTAAGGCATGTT-1_paired',
#  'ATCACTAAGTGAGCGG-1_paired',
#  'ATCAGGTTCCGTTAAA-1_paired',
#  'ATCAGGTTCTTAAGTG-1_paired',
#  'ATCATCAAGACTATTG-1_paired',
#  'ATCATCAAGGGACTAA-1_paired',
#  'ATCATGTCACAGAACG-1_paired',
#  'ATCATGTCAGCCAGTT-1_paired',
#  'ATCATGTCAGGCGATA-1_paired',
#  'ATCCACCTCAGCTAAC-1_paired',
#  'ATCCACCTCATTGCGG-1_paired',
#  'ATCCACCTCTCGACCT-1_paired',
#  'ATCCATAAGGATCCGC-1_paired',
#  'ATCCATAAGGTCCTGA-1_paired',
#  'ATCCCGCGTAAAGCAA-1_paired',
#  'ATCCCGCGTGCCTCAC-1_paired',
#  'ATCCCGCGTTGGTTCT-1_paired',
#  'ATCCGTGAGGATGATG-1_paired',
#  'ATCCGTGAGGTCCTAG-1_paired',
#  'ATCCGTGAGTCGCTAG-1_paired',
#  'ATCCTGACACTTGTTC-1_paired',
#  'ATCCTGACAGGACACA-1_paired',
#  'ATCCTGACATGACTAT-1_paired',
#  'ATCGAGGCAGGCGATA-1_paired',
#  'ATCGAGGCAGGTTATT-1_paired',
#  'ATCGAGGCAGTTTGGC-1_paired',
#  'ATCGAGGCATCAGCAC-1_paired',
#  'ATCGCCCGTGGGTGAA-1_paired',
#  'ATCGCCCGTTCGCGCT-1_paired',
#  'ATCGCCCGTTTGTCTA-1_paired',
#  'ATCTATGAGTTTAACG-1_paired',
#  'ATCTTTGGTAAGCTTG-1_paired',
#  'ATGAAGCCACATGCTA-1_paired',
#  'ATGAAGCCAGGAACAT-1_paired',
#  'ATGAAGCCAGGACCTT-1_paired',
#  'ATGAAGTAGAAACTGG-1_paired',
#  'ATGAATGCACGTAATT-1_paired',
#  'ATGACAACAGGCATGA-1_paired',
#  'ATGACCAGTTAATGAC-1_paired',
#  'ATGACCAGTTACATCC-1_paired',
#  'ATGACGAAGCGAGTAA-1_paired',
#  'ATGACGAAGCGCCTTT-1_paired',
#  'ATGATGACAAACAACA-1_paired',
#  'ATGATGACAATTGACT-1_paired',
#  'ATGATGACACTGGCCA-1_paired',
#  'ATGATGGAGCGAGTAA-1_paired',
#  'ATGATGGAGCTTACTT-1_paired',
#  'ATGCAAACAGGACCAA-1_paired',
#  'ATGCAAACAGTCTATG-1_paired',
#  'ATGCAAACATGCTTAG-1_paired',
#  'ATGCAGGCAGTTTGTG-1_paired',
#  'ATGCATTCAATAGCCC-1_paired',
#  'ATGCCTGAGTAACCAC-1_paired',
#  'ATGCGATTCATGTTTC-1_paired',
#  'ATGCGATTCTGTAAGC-1_paired',
#  'ATGCTTAAGGTCATTA-1_paired',
#  'ATGCTTAAGTCATTTC-1_paired',
#  'ATGGCCCAGATGGAGC-1_paired',
#  'ATGGCCCAGCATGTTA-1_paired',
#  'ATGGCTAGTGAAGCCT-1_paired',
#  'ATGGCTAGTTGCGGAT-1_paired',
#  'ATGGCTGTCAAACCTA-1_paired',
#  'ATGGCTGTCATTACGA-1_paired',
#  'ATGGCTGTCCTTGTTG-1_paired',
#  'ATGGTCTAGTAGCGGG-1_paired',
#  'ATGGTGCGTCCTTCTC-1_paired',
#  'ATGGTGCGTGTTAAAC-1_paired',
#  'ATGGTGCGTTACCTGT-1_paired',
#  'ATGGTTATCCTCCATA-1_paired',
#  'ATGGTTATCTGGTCCT-1_paired',
#  'ATGGTTATCTTGCTAT-1_paired',
#  'ATGTAACGTAATCACG-1_paired',
#  'ATGTAACGTGATTACG-1_paired',
#  'ATGTAACGTTGCACGG-1_paired',
#  'ATGTAACGTTTCCGGC-1_paired',
#  'ATGTAAGCAGGAACCA-1_paired',
#  'ATGTAAGCAGTAATAG-1_paired',
#  'ATGTCAATCAGCATTA-1_paired',
#  'ATGTCAATCATTATGG-1_paired',
#  'ATGTCAATCGGCCATA-1_paired',
#  'ATGTCAATCTTTGACT-1_paired',
#  'ATGTCATCATCTTGAG-1_paired',
#  'ATGTCCACAATTGAGA-1_paired',
#  'ATGTGAGAGGGTTATC-1_paired',
#  'ATGTGAGAGTCATGCG-1_paired',
#  'ATGTTGTCACCACAAC-1_paired',
#  'ATGTTTGAGCCAGGTC-1_paired',
#  'ATGTTTGAGGGTGGAT-1_paired',
#  'ATGTTTGAGTCCTTCA-1_paired',
#  'ATTAACCCATTATGAC-1_paired',
#  'ATTACCCGTATCTGGA-1_paired',
#  'ATTACCCGTGAAGCCT-1_paired',
#  'ATTACCCGTGCATTAG-1_paired',
#  'ATTACCCGTTCACTGT-1_paired',
#  'ATTACCGCAAACGCGA-1_paired',
#  'ATTACCGCAGGCCAAA-1_paired',
#  'ATTACGTCAATAATGG-1_paired',
#  'ATTACTGAGGCTTAAC-1_paired',
#  'ATTACTGAGTGGCGGA-1_paired',
#  'ATTAGCGGTCAAAGGG-1_paired',
#  'ATTAGCGGTGCATCGG-1_paired',
#  'ATTAGCTCAAGCCACT-1_paired',
#  'ATTAGCTCATTAAACC-1_paired',
#  'ATTAGGTGTAACTACG-1_paired',
#  'ATTAGGTGTCACAGCG-1_paired',
#  'ATTAGTCCAAGCCAGA-1_paired',
#  'ATTAGTCCACTTAACG-1_paired',
#  'ATTAGTCCATGAATAG-1_paired',
#  'ATTATCCTCATGCTAA-1_paired',
#  'ATTCAACCACCAACCG-1_paired',
#  'ATTCAACCAGAGAGCC-1_paired',
#  'ATTCAACCAGGACCAA-1_paired',
#  'ATTCAACCAGTAGGAT-1_paired',
#  'ATTCACTTCTGGTCCT-1_paired',
#  'ATTCACTTCTTGCATT-1_paired',
#  'ATTCATGAGCTTTGGG-1_paired',
#  'ATTCATGAGGTCCAAT-1_paired',
#  'ATTCATGAGTTAGTTG-1_paired',
#  'ATTCCGGAGATGGAGC-1_paired',
#  'ATTCCTAGTAAGCACC-1_paired',
#  'ATTCCTAGTGAATCGC-1_paired',
#  'ATTCCTAGTGTCCTGC-1_paired',
#  'ATTCCTCCAAGGAATC-1_paired',
#  'ATTCCTCCAATTGAGA-1_paired',
#  'ATTCCTCCACCTCACC-1_paired',
#  'ATTCCTCCACTAGCGT-1_paired',
#  'ATTCCTCCATGGCCTG-1_paired',
#  'ATTCGTTTCCAATTAG-1_paired',
#  'ATTCGTTTCCTTAAGA-1_paired',
#  'ATTGAAGCAGGCCTTG-1_paired',
#  'ATTGAAGCAGTTGCGT-1_paired',
#  'ATTGAAGCATCACAGC-1_paired',
#  'ATTGAAGCATTGTCCT-1_paired',
#  'ATTGACTCACTGACTA-1_paired',
#  'ATTGACTCATCGCTTT-1_paired',
#  'ATTGCGCCAAACGGGC-1_paired',
#  'ATTGCGCCATCAATCG-1_paired',
#  'ATTGCGCCATTAAGTC-1_paired',
#  'ATTGCTCGTCTAACAG-1_paired',
#  'ATTGCTCGTTATAGCG-1_paired',
#  'ATTGTCCGTCTTTGAC-1_paired',
#  'ATTGTGATCATGCTTT-1_paired',
#  'ATTGTGATCCTGATTT-1_paired',
#  'ATTGTGATCGATATTG-1_paired',
#  'ATTGTGATCTAAGTCA-1_paired',
#  'ATTTAGGTCGCAACAT-1_paired',
#  'ATTTAGGTCTCCATGC-1_paired',
#  'ATTTGCAAGGAGGGTT-1_paired',
#  'ATTTGCAAGGTTAGCT-1_paired',
#  'ATTTGTGAGGAGGTTA-1_paired',
#  'CAAACAACACCCTCAC-1_paired',
#  'CAAACAACATTGTGCA-1_paired',
#  'CAAACACTCACTTCAT-1_paired',
#  'CAAACACTCCGCCTAT-1_paired',
#  'CAAACATGTAGCCTAA-1_paired',
#  'CAAACATGTCACACCC-1_paired',
#  'CAAACATGTTGGTTGA-1_paired',
#  'CAAACATGTTTAACGG-1_paired',
#  'CAAACATGTTTGGGCG-1_paired',
#  'CAAACCGTCATTACTC-1_paired',
#  'CAAACGCGTGACATAT-1_paired',
#  'CAAACTGGTAACAGGG-1_paired',
#  'CAAACTGGTGATGAGG-1_paired',
#  'CAAACTGGTGCAATAT-1_paired',
#  'CAAAGCGCAAGCGAGC-1_paired',
#  'CAAAGCGCATTAAACC-1_paired',
#  'CAAAGGATCATGCCTC-1_paired',
#  'CAAAGGATCATTATGG-1_paired',
#  'CAAAGGATCGGTTTGG-1_paired',
#  'CAAAGTGAGGAGCATA-1_paired',
#  'CAAAGTGAGGAGGTTA-1_paired',
#  'CAAAGTGAGTTAGGCT-1_paired',
#  'CAAATCATCATCCACC-1_paired',
#  'CAAATCATCGCTATAA-1_paired',
#  'CAACAATGTACTGATG-1_paired',
#  'CAACAATGTGTTGCTT-1_paired',
#  'CAACAGGCATAATTGC-1_paired',
#  'CAACAGGCATTTAAGC-1_paired',
#  'CAACCCGCATAGCAGG-1_paired',
#  'CAACCCGCATCTAGCA-1_paired',
#  'CAACCCGCATGGCCTG-1_paired',
#  'CAACCCTTCAGGATGA-1_paired',
#  'CAACCCTTCTCAATAG-1_paired',
#  'CAACTAGGTAAGTCGC-1_paired',
#  'CAACTAGGTCAAGTAT-1_paired',
#  'CAACTAGGTGATCAGC-1_paired',
#  'CAACTAGGTGGTGAGA-1_paired',
#  'CAAGCTAGTACGCGCA-1_paired',
#  'CAAGCTAGTGACCTGG-1_paired',
#  'CAAGCTAGTTCCTGTG-1_paired',
#  'CAAGGCTGTTTAAAGC-1_paired',
#  'CAAGGGAGTTACGCGG-1_paired',
#  'CAAGGGAGTTTGCGCC-1_paired',
#  'CAAGGTAAGAGAAGGG-1_paired',
#  'CAAGGTAAGATTGAGG-1_paired',
#  'CAAGGTAAGTGAGGTA-1_paired',
#  'CAAGGTTTCCACAATA-1_paired',
#  'CAAGGTTTCTTTGAGA-1_paired',
#  'CAAGTAACACAACAGG-1_paired',
#  'CAAGTAACATAAGCAA-1_paired',
#  'CAAGTGAAGGCCTTAG-1_paired',
#  'CAAGTTATCCACCTGT-1_paired',
#  'CAAGTTATCGGTCAGC-1_paired',
#  'CAATAAGCACTGACCG-1_paired',
#  'CAATAAGCATTAGCCA-1_paired',
#  'CAATAGCTCACATTGA-1_paired',
#  'CAATAGCTCGCTAGAT-1_paired',
#  'CAATAGCTCTTTAAGG-1_paired',
#  'CAATATGTCGAAGTGA-1_paired',
#  'CAATCCCTCCGCCTCA-1_paired',
#  'CAATCCCTCCTAAGTA-1_paired',
#  'CAATCCTGTAGTAAGA-1_paired',
#  'CAATCGCCAGGCGAGT-1_paired',
#  'CAATCTAAGGAATAAC-1_paired',
#  'CAATCTAAGGATAAAC-1_paired',
#  'CAATCTAAGGTGTTAC-1_paired',
#  'CAATCTAAGTAATCCA-1_paired',
#  'CAATCTAAGTAGCTTA-1_paired',
#  'CAATCTAAGTTATCTC-1_paired',
#  'CAATGAACATTGCAGC-1_paired',
#  'CAATGACTCCCTCGCA-1_paired',
#  'CAATGACTCCTGATGG-1_paired',
#  'CAATGCCCAAATGCCC-1_paired',
#  'CAATGCCCAACACCTA-1_paired',
#  'CAATGCCCATTGTTGG-1_paired',
#  'CAATGTCAGCTCGCTT-1_paired',
#  'CAATGTCAGTGAAGTG-1_paired',
#  'CAATGTGGTATTACCC-1_paired',
#  'CACAAGCGTCTTGCAT-1_paired',
#  'CACAAGCGTTACTTCA-1_paired',
#  'CACAAGCGTTTAGTCC-1_paired',
#  'CACAATATCGATCAGT-1_paired',
#  'CACAATATCTAACCAA-1_paired',
#  'CACAATATCTAGCTTT-1_paired',
#  'CACAGGCTCTCGCCTG-1_paired',
#  'CACATAATCAAAGGCA-1_paired',
#  'CACATAATCTTGCAAA-1_paired',
#  'CACATACAGGCCGGAA-1_paired',
#  'CACATTAAGGCATGAA-1_paired',
#  'CACCGGTAGGACGTAA-1_paired',
#  'CACCGGTAGGACTAAG-1_paired',
#  'CACCTCAGTGAATCGC-1_paired',
#  'CACCTCAGTGCTAGCG-1_paired',
#  'CACCTCAGTTAGAGCC-1_paired',
#  'CACCTGTTCAGCAAAG-1_paired',
#  'CACCTGTTCCTGTTCA-1_paired',
#  'CACCTGTTCTTTAAGG-1_paired',
#  'CACGCAATCAAGTGAG-1_paired',
#  'CACGCAATCTCGCCTG-1_paired',
#  'CACTAAGGTTGTAAAC-1_paired',
#  'CACTAGCCACCATATG-1_paired',
#  'CACTAGCCATCAATCG-1_paired',
#  'CACTGACCAACACCTA-1_paired',
#  'CACTTAAAGCGCTAAT-1_paired',
#  'CACTTAAAGGATTGAG-1_paired',
#  'CACTTAAAGTCATTAG-1_paired',
#  'CACTTTGTCCCGTTAC-1_paired',
#  'CACTTTGTCCTTCGTA-1_paired',
#  'CACTTTGTCGCTTGCT-1_paired',
#  'CAGAACCGTTGAGCCG-1_paired',
#  'CAGAATCTCGCAACAT-1_paired',
#  'CAGATTCAGCGAGCGA-1_paired',
#  'CAGCAAGCAGGATTAA-1_paired',
#  'CAGCATGTCACAGGAA-1_paired',
#  'CAGCATGTCGGTTTGG-1_paired',
#  'CAGCATGTCGTTAACA-1_paired',
#  'CAGCATTAGGCTGTGC-1_paired',
#  'CAGCATTAGTAACGAG-1_paired',
#  'CAGCCAATCCCTGTTA-1_paired',
#  'CAGCCTAAGCGCAATT-1_paired',
#  'CAGCCTAAGGCCCAGT-1_paired',
#  'CAGCTAAGTGTTGTAG-1_paired',
#  'CAGCTAAGTTGTAAAC-1_paired',
#  'CAGGACCTCAATCATG-1_paired',
#  'CAGGACCTCCTAATGA-1_paired',
#  'CAGGACCTCTAAGGTC-1_paired',
#  'CAGGCTGGTTCACTGT-1_paired',
#  'CAGGCTGGTTTGGGTA-1_paired',
#  'CAGGGTGAGACTAAGG-1_paired',
#  'CAGGGTGAGCTATGAC-1_paired',
#  'CAGGGTGAGTGAACGA-1_paired',
#  'CAGGTCCAGAAGCTAG-1_paired',
#  'CAGGTCCAGCGCTCAA-1_paired',
#  'CAGGTCCAGGCGGGTA-1_paired',
#  'CAGGTCCAGTCATTTC-1_paired',
#  'CAGGTCCAGTTAGAGG-1_paired',
#  'CAGGTGGAGACAACGA-1_paired',
#  'CAGGTTAGTGAACAAA-1_paired',
#  'CAGGTTTAGCAACATC-1_paired',
#  'CAGGTTTAGCGTGCGT-1_paired',
#  'CAGGTTTAGGTTTGCG-1_paired',
#  'CAGTATGGTGCTCCAC-1_paired',
#  'CATAACGGTAACGAGG-1_paired',
#  'CATAACGGTGTTTGCT-1_paired',
#  'CATAAGCTCGTCAAGT-1_paired',
#  'CATAAGCTCTAAGTCA-1_paired',
#  'CATAAGCTCTTGAGGT-1_paired',
#  'CATAATCCACAACAAA-1_paired',
#  'CATAATCCACTGACCG-1_paired',
#  'CATAATCCATAGTCAT-1_paired',
#  'CATAATGTCAGGTTTA-1_paired',
#  'CATAATGTCCGTCCAT-1_paired',
#  'CATAGACTCAACCAAC-1_paired',
#  'CATAGACTCGTGCTTC-1_paired',
#  'CATAGACTCTTTGAGA-1_paired',
#  'CATAGCTAGCCAGTAT-1_paired',
#  'CATAGCTAGGTGAAGC-1_paired',
#  'CATAGCTAGTTCCCAC-1_paired',
#  'CATAGGCGTTTATGGG-1_paired',
#  'CATAGGTTCAGGTTTA-1_paired',
#  'CATAGGTTCTCAATAG-1_paired',
#  'CATAGTCAGGAACCGG-1_paired',
#  'CATATCGCAATTATGC-1_paired',
#  'CATATCGCACCAGCAT-1_paired',
#  'CATATCGCATTAGGTT-1_paired',
#  'CATATCGCATTGTCAG-1_paired',
#  'CATCAATCACCTAATG-1_paired',
#  'CATCAATCAGGCTGTT-1_paired',
#  'CATCAATCATAATCGT-1_paired',
#  'CATCACACAACAGGTG-1_paired',
#  'CATCACACAATTAGCT-1_paired',
#  ...]

# %%
df_meta.apply(lambda row: row.index+'_paired', axis=1)
# Out:
# AAACAGCCAACCGCCA-1    Index(['n_counts_paired', 'celltype_paired',
#  ...
# AAACAGCCAAGGTCGA-1    Index(['n_counts_paired', 'celltype_paired',
#  ...
# AAACAGCCAGGAACAT-1    Index(['n_counts_paired', 'celltype_paired',
#  ...
# AAACAGCCATATTGAC-1    Index(['n_counts_paired', 'celltype_paired',
#  ...
# AAACAGCCATGGTTAT-1    Index(['n_counts_paired', 'celltype_paired',
#  ...
#                                             ...
# TTTGTGGCATAATCGT-1    Index(['n_counts_paired', 'celltype_paired',
#  ...
# TTTGTGGCATTTGCTC-1    Index(['n_counts_paired', 'celltype_paired',
#  ...
# TTTGTGTTCAATGACC-1    Index(['n_counts_paired', 'celltype_paired',
#  ...
# TTTGTTGGTGGAGCAA-1    Index(['n_counts_paired', 'celltype_paired',
#  ...
# TTTGTTGGTTAGAGCC-1    Index(['n_counts_paired', 'celltype_paired',
#  ...
# Length: 3365, dtype: object

# %%
df_meta['paired_label'] = newname

# %%
df_meta
# Out:
#                     n_counts         celltype  velo_s_norm_self_transition  \
# AAACAGCCAACCGCCA-1     681.0      Upper Layer                     0.057197
# AAACAGCCAAGGTCGA-1     296.0   RG, Astro, OPC                     0.114116
# AAACAGCCAGGAACAT-1     504.0     Deeper Layer                     0.082940
# AAACAGCCATATTGAC-1     321.0     Deeper Layer                     0.106146
# AAACAGCCATGGTTAT-1     432.0         Subplate                     0.103904
# ...                      ...              ...                          ...
# TTTGTGGCATAATCGT-1    1248.0  Ependymal cells                     0.089063
# TTTGTGGCATTTGCTC-1     451.0      Upper Layer                     0.049716
# TTTGTGTTCAATGACC-1     369.0              IPC                     0.130270
# TTTGTTGGTGGAGCAA-1     513.0     Deeper Layer                     0.038342
# TTTGTTGGTTAGAGCC-1     204.0      Upper Layer                     0.021775
#
#                     root_cells  end_points  velo_s_norm_pseudotime  \
# AAACAGCCAACCGCCA-1    0.037962    0.086987                0.857504
# AAACAGCCAAGGTCGA-1    0.049274    0.396248                0.213945
# AAACAGCCAGGAACAT-1    0.020133    0.338813                0.958743
# AAACAGCCATATTGAC-1    0.003566    0.735495                0.981135
# AAACAGCCATGGTTAT-1    0.036739    0.134693                0.848509
# ...                        ...         ...                     ...
# TTTGTGGCATAATCGT-1    0.556196    0.005403                0.889134
# TTTGTGGCATTTGCTC-1    0.013520    0.407998                0.861768
# TTTGTGTTCAATGACC-1    0.499946    0.019731                0.604746
# TTTGTTGGTGGAGCAA-1    0.062265    0.113687                0.948574
# TTTGTTGGTTAGAGCC-1    0.038538    0.360803                0.895777
#
#                     latent_time       binned  time_label  \
# AAACAGCCAACCGCCA-1     0.604954  (0.6, 0.65]          12
# AAACAGCCAAGGTCGA-1     0.281341  (0.25, 0.3]           5
# AAACAGCCAGGAACAT-1     0.851495  (0.85, 0.9]          17
# AAACAGCCATATTGAC-1     0.982605  (0.95, 1.0]          19
# AAACAGCCATGGTTAT-1     0.549869  (0.5, 0.55]          10
# ...                         ...          ...         ...
# TTTGTGGCATAATCGT-1     0.454965  (0.45, 0.5]           9
# TTTGTGGCATTTGCTC-1     0.598991  (0.55, 0.6]          11
# TTTGTGTTCAATGACC-1     0.291581  (0.25, 0.3]           5
# TTTGTTGGTGGAGCAA-1     0.776289  (0.75, 0.8]          15
# TTTGTTGGTTAGAGCC-1     0.719392  (0.7, 0.75]          14
#
#                                  paired_label
# AAACAGCCAACCGCCA-1  AAACAGCCAACCGCCA-1_paired
# AAACAGCCAAGGTCGA-1  AAACAGCCAAGGTCGA-1_paired
# AAACAGCCAGGAACAT-1  AAACAGCCAGGAACAT-1_paired
# AAACAGCCATATTGAC-1  AAACAGCCATATTGAC-1_paired
# AAACAGCCATGGTTAT-1  AAACAGCCATGGTTAT-1_paired
# ...                                       ...
# TTTGTGGCATAATCGT-1  TTTGTGGCATAATCGT-1_paired
# TTTGTGGCATTTGCTC-1  TTTGTGGCATTTGCTC-1_paired
# TTTGTGTTCAATGACC-1  TTTGTGTTCAATGACC-1_paired
# TTTGTTGGTGGAGCAA-1  TTTGTTGGTGGAGCAA-1_paired
# TTTGTTGGTTAGAGCC-1  TTTGTTGGTTAGAGCC-1_paired
#
# [3365 rows x 10 columns]

# %%
sub_df = df_meta[['paired_label', "time_label"]]
sub_df = sub_df.set_index("paired_label")
sub_df.head()
# Out:
#                            time_label
# paired_label
# AAACAGCCAACCGCCA-1_paired          12
# AAACAGCCAAGGTCGA-1_paired           5
# AAACAGCCAGGAACAT-1_paired          17
# AAACAGCCATATTGAC-1_paired          19
# AAACAGCCATGGTTAT-1_paired          10

# %%
sub_df.loc['AAACAGCCAACCGCCA-1_paired',:]
# Out:
# time_label    12
# Name: AAACAGCCAACCGCCA-1_paired, dtype: int64

# %%
adata_mvi.var["time_label"] = sub_df
adata_mvi
# Out:
# AnnData object with n_obs × n_vars = 3365 × 176722
#     obs: 'celltype', 'batch_id', 'modality', 'time_label'
#     var: 'gene_ids', 'feature_types', 'modality', 'time_label'

# %%
adata_multi = sc.read_h5ad("halo/E18_mouse_Brain/multiomic.h5ad")
adata_multi.obs["batch_id"] = 1
adata_multi.var["modality"] =adata_multi.var["feature_types"]
adata_mvi = scvi.data.organize_multiome_anndatas(adata_multi)
df_meta= pd.read_csv("halo/E18_mouse_Brain/RNA/metadata.tsv",sep = "\t",index_col=0)

## add time label
binned_time = df_meta.binned.unique()
name_dict = {}
i = 0
for time in sorted(binned_time):
    name_dict[time] = i
    i += 1
name_dict 

## add time label to dfs
df_meta['time_label'] = df_meta.apply(lambda row: name_dict[row.binned], axis=1)
## change name:
name = np.array(df_meta.index)
newname = [n+"_paired" for n in name]
df_meta['paired_label'] = newname

## get sub dataframe
sub_df = df_meta[['paired_label', "time_label"]]
sub_df = sub_df.set_index("paired_label")
adata_mvi.obs["time_label"] = sub_df

# %%
adata_mvi.obs
# Out:
#                                   celltype  batch_id modality  time_label
# AAACAGCCAACCGCCA-1_paired      Upper Layer         1   paired          12
# AAACAGCCAAGGTCGA-1_paired   RG, Astro, OPC         1   paired           5
# AAACAGCCAGGAACAT-1_paired     Deeper Layer         1   paired          17
# AAACAGCCATATTGAC-1_paired     Deeper Layer         1   paired          19
# AAACAGCCATGGTTAT-1_paired         Subplate         1   paired          10
# ...                                    ...       ...      ...         ...
# TTTGTGGCATAATCGT-1_paired  Ependymal cells         1   paired           9
# TTTGTGGCATTTGCTC-1_paired      Upper Layer         1   paired          11
# TTTGTGTTCAATGACC-1_paired              IPC         1   paired           5
# TTTGTTGGTGGAGCAA-1_paired     Deeper Layer         1   paired          15
# TTTGTTGGTTAGAGCC-1_paired      Upper Layer         1   paired          14
#
# [3365 rows x 4 columns]
